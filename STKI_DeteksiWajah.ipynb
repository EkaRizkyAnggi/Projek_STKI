# %% [markdown]
# ## Mounting Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Install Requirements

# %%
# !pip install mtcnn
# Out:
# Requirement already satisfied: mtcnn in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (1.0.0)
# Requirement already satisfied: joblib>=1.4.2 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from mtcnn) (1.4.2)
# Requirement already satisfied: lz4>=4.3.3 in c:\users\acer\appdata\local\programs\python\python310\lib\site-packages (from mtcnn) (4.3.3)

# %% [markdown]
# ## Import Library

# %%
import os
import shutil
from mtcnn import MTCNN
from PIL import Image
import numpy as np
import random
import matplotlib.pyplot as plt

# %% [markdown]
# ## Deteksi Wajah

# %%
# Path asal dataset
base_path = 'PROJEK_STKI'
dataset_final_path = os.path.join(base_path, 'DatasetFinal')

# Path untuk hasil deteksi wajah
detectface_path = os.path.join(dataset_final_path, 'detectface')

# Inisialisasi MTCNN
detector = MTCNN()

# %%
# Fungsi untuk memastikan folder ada
def ensure_folder_exists(folder_path):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

# Fungsi untuk mendeteksi wajah dan menyimpannya
def detect_and_save_faces(source_folder, destination_folder, category):
    total_files = 0
    detected_files = 0
    undetected_files = 0
    detected_file_paths = []

    print(f"\nProses Deteksi Wajah untuk kategori: {category}")

    for subject in os.listdir(source_folder):
        subject_path = os.path.join(source_folder, subject)

        if os.path.isdir(subject_path):
            ensure_folder_exists(os.path.join(destination_folder, subject))

            for file_name in os.listdir(subject_path):
                if file_name.endswith(('.png', '.jpg', '.jpeg')):
                    total_files += 1
                    file_path = os.path.join(subject_path, file_name)

                    try:
                        # Buka gambar dan lakukan deteksi wajah
                        img = Image.open(file_path)
                        img = np.array(img)
                        faces = detector.detect_faces(img)

                        # Jika wajah terdeteksi, simpan file ke folder tujuan
                        if faces:
                            detected_files += 1
                            img_pil = Image.fromarray(img)
                            img_pil.save(os.path.join(destination_folder, subject, file_name))
                            detected_file_paths.append(file_path)
                            print(f"Deteksi wajah berhasil: {file_name} di folder {subject}")
                        else:
                            undetected_files += 1
                            print(f"Tidak ada wajah terdeteksi: {file_name} di folder {subject}")
                    except Exception as e:
                        print(f"Error saat mendeteksi {file_name}: {e}")
                        undetected_files += 1

    return total_files, detected_files, undetected_files, detected_file_paths

# %%
# Pastikan folder detectface ada
ensure_folder_exists(detectface_path)

# Proses deteksi wajah untuk kategori Drowsy dan Non Drowsy
categories = ['Drowsy', 'Non Drowsy']

# Loop untuk kategori Drowsy dan Non Drowsy
total_all_files = 0
detected_all_files = 0
undetected_all_files = 0
detected_file_paths_all = {'Drowsy': [], 'Non Drowsy': []}

for category in categories:
    print(f"\n--- Deteksi Wajah untuk Kategori: {category} ---")
    source_category_path = os.path.join(dataset_final_path, 'train', category)
    destination_category_path = os.path.join(detectface_path, category)

    # Pastikan folder kategori Drowsy dan Non Drowsy ada di detectface
    ensure_folder_exists(destination_category_path)

    total_files, detected_files, undetected_files, detected_file_paths = detect_and_save_faces(
        source_category_path, destination_category_path, category)

    total_all_files += total_files
    detected_all_files += detected_files
    undetected_all_files += undetected_files
    detected_file_paths_all[category] = detected_file_paths
# Out:
# --- Deteksi Wajah untuk Kategori: Drowsy ---
#
# Proses Deteksi Wajah untuk kategori: Drowsy
# Deteksi wajah berhasil: H0001.png di folder H
# Deteksi wajah berhasil: H0002.png di folder H
# Deteksi wajah berhasil: H0003.png di folder H
# Deteksi wajah berhasil: H0004.png di folder H
# Deteksi wajah berhasil: H0005.png di folder H
# Deteksi wajah berhasil: H0006.png di folder H
# Deteksi wajah berhasil: H0007.png di folder H
# Deteksi wajah berhasil: H0008.png di folder H
# Deteksi wajah berhasil: H0009.png di folder H
# Deteksi wajah berhasil: H0010.png di folder H
# Deteksi wajah berhasil: H0011.png di folder H
# Deteksi wajah berhasil: H0016.png di folder H
# Deteksi wajah berhasil: H0017.png di folder H
# Deteksi wajah berhasil: H0018.png di folder H
# Deteksi wajah berhasil: H0019.png di folder H
# Deteksi wajah berhasil: H0020.png di folder H
# Deteksi wajah berhasil: H0022.png di folder H
# Deteksi wajah berhasil: H0023.png di folder H
# Deteksi wajah berhasil: H0026.png di folder H
# Deteksi wajah berhasil: H0027.png di folder H
# Deteksi wajah berhasil: H0028.png di folder H
# Deteksi wajah berhasil: H0029.png di folder H
# Deteksi wajah berhasil: H0030.png di folder H
# Deteksi wajah berhasil: H0031.png di folder H
# Deteksi wajah berhasil: H0032.png di folder H
# Deteksi wajah berhasil: H0037.png di folder H
# Deteksi wajah berhasil: H0038.png di folder H
# Deteksi wajah berhasil: H0039.png di folder H
# Deteksi wajah berhasil: H0040.png di folder H
# Deteksi wajah berhasil: H0041.png di folder H
# Deteksi wajah berhasil: H0042.png di folder H
# Deteksi wajah berhasil: H0043.png di folder H
# Deteksi wajah berhasil: H0045.png di folder H
# Deteksi wajah berhasil: H0046.png di folder H
# Deteksi wajah berhasil: H0047.png di folder H
# Deteksi wajah berhasil: H0048.png di folder H
# Deteksi wajah berhasil: H0049.png di folder H
# Deteksi wajah berhasil: H0050.png di folder H
# Deteksi wajah berhasil: H0052.png di folder H
# Deteksi wajah berhasil: H0053.png di folder H
# Deteksi wajah berhasil: H0055.png di folder H
# Deteksi wajah berhasil: H0056.png di folder H
# Deteksi wajah berhasil: H0058.png di folder H
# Deteksi wajah berhasil: H0059.png di folder H
# Deteksi wajah berhasil: H0060.png di folder H
# Deteksi wajah berhasil: H0061.png di folder H
# Deteksi wajah berhasil: H0062.png di folder H
# Deteksi wajah berhasil: H0069.png di folder H
# Deteksi wajah berhasil: H0070.png di folder H
# Deteksi wajah berhasil: H0071.png di folder H
# Deteksi wajah berhasil: H0072.png di folder H
# Deteksi wajah berhasil: H0074.png di folder H
# Deteksi wajah berhasil: H0077.png di folder H
# Deteksi wajah berhasil: H0078.png di folder H
# Deteksi wajah berhasil: H0083.png di folder H
# Deteksi wajah berhasil: H0084.png di folder H
# Deteksi wajah berhasil: H0086.png di folder H
# Deteksi wajah berhasil: H0087.png di folder H
# Deteksi wajah berhasil: H0089.png di folder H
# Deteksi wajah berhasil: H0090.png di folder H
# Deteksi wajah berhasil: H0091.png di folder H
# Deteksi wajah berhasil: H0092.png di folder H
# Deteksi wajah berhasil: H0093.png di folder H
# Deteksi wajah berhasil: H0094.png di folder H
# Deteksi wajah berhasil: H0095.png di folder H
# Deteksi wajah berhasil: H0096.png di folder H
# Deteksi wajah berhasil: H0097.png di folder H
# Deteksi wajah berhasil: H0098.png di folder H
# Deteksi wajah berhasil: H0101.png di folder H
# Deteksi wajah berhasil: H0102.png di folder H
# Deteksi wajah berhasil: H0103.png di folder H
# Deteksi wajah berhasil: H0105.png di folder H
# Deteksi wajah berhasil: H0106.png di folder H
# Deteksi wajah berhasil: H0107.png di folder H
# Deteksi wajah berhasil: H0109.png di folder H
# Deteksi wajah berhasil: H0110.png di folder H
# Deteksi wajah berhasil: H0111.png di folder H
# Deteksi wajah berhasil: H0112.png di folder H
# Deteksi wajah berhasil: H0114.png di folder H
# Deteksi wajah berhasil: H0115.png di folder H
# Deteksi wajah berhasil: H0116.png di folder H
# Deteksi wajah berhasil: H0118.png di folder H
# Deteksi wajah berhasil: H0119.png di folder H
# Deteksi wajah berhasil: H0120.png di folder H
# Deteksi wajah berhasil: H0121.png di folder H
# Deteksi wajah berhasil: H0122.png di folder H
# Deteksi wajah berhasil: H0123.png di folder H
# Deteksi wajah berhasil: H0125.png di folder H
# Deteksi wajah berhasil: H0126.png di folder H
# Deteksi wajah berhasil: H0127.png di folder H
# Deteksi wajah berhasil: H0128.png di folder H
# Deteksi wajah berhasil: H0129.png di folder H
# Deteksi wajah berhasil: H0130.png di folder H
# Deteksi wajah berhasil: H0139.png di folder H
# Deteksi wajah berhasil: H0140.png di folder H
# Deteksi wajah berhasil: H0143.png di folder H
# Deteksi wajah berhasil: H0144.png di folder H
# Deteksi wajah berhasil: H0155.png di folder H
# Deteksi wajah berhasil: H0156.png di folder H
# Deteksi wajah berhasil: H0158.png di folder H
# Deteksi wajah berhasil: H0159.png di folder H
# Deteksi wajah berhasil: H0160.png di folder H
# Deteksi wajah berhasil: H0166.png di folder H
# Deteksi wajah berhasil: H0167.png di folder H
# Deteksi wajah berhasil: H0168.png di folder H
# Deteksi wajah berhasil: H0170.png di folder H
# Deteksi wajah berhasil: M0002.png di folder M
# Deteksi wajah berhasil: M0003.png di folder M
# Deteksi wajah berhasil: M0004.png di folder M
# Deteksi wajah berhasil: M0005.png di folder M
# Deteksi wajah berhasil: M0007.png di folder M
# Deteksi wajah berhasil: M0009.png di folder M
# Deteksi wajah berhasil: M0010.png di folder M
# Deteksi wajah berhasil: M0011.png di folder M
# Deteksi wajah berhasil: M0014.png di folder M
# Deteksi wajah berhasil: M0015.png di folder M
# Deteksi wajah berhasil: M0016.png di folder M
# Deteksi wajah berhasil: M0018.png di folder M
# Deteksi wajah berhasil: M0019.png di folder M
# Deteksi wajah berhasil: M0020.png di folder M
# Deteksi wajah berhasil: M0022.png di folder M
# Deteksi wajah berhasil: M0024.png di folder M
# Deteksi wajah berhasil: M0025.png di folder M
# Deteksi wajah berhasil: M0026.png di folder M
# Deteksi wajah berhasil: M0029.png di folder M
# Deteksi wajah berhasil: M0030.png di folder M
# Deteksi wajah berhasil: M0031.png di folder M
# Deteksi wajah berhasil: M0033.png di folder M
# Deteksi wajah berhasil: M0034.png di folder M
# Deteksi wajah berhasil: M0035.png di folder M
# Deteksi wajah berhasil: M0036.png di folder M
# Deteksi wajah berhasil: M0037.png di folder M
# Deteksi wajah berhasil: M0040.png di folder M
# Deteksi wajah berhasil: M0041.png di folder M
# Deteksi wajah berhasil: M0043.png di folder M
# Deteksi wajah berhasil: M0045.png di folder M
# Deteksi wajah berhasil: M0046.png di folder M
# Deteksi wajah berhasil: M0047.png di folder M
# Deteksi wajah berhasil: M0048.png di folder M
# Deteksi wajah berhasil: M0049.png di folder M
# Deteksi wajah berhasil: M0050.png di folder M
# Deteksi wajah berhasil: M0051.png di folder M
# Deteksi wajah berhasil: M0052.png di folder M
# Deteksi wajah berhasil: M0053.png di folder M
# Deteksi wajah berhasil: M0055.png di folder M
# Deteksi wajah berhasil: M0057.png di folder M
# Deteksi wajah berhasil: M0058.png di folder M
# Deteksi wajah berhasil: M0059.png di folder M
# Deteksi wajah berhasil: M0062.png di folder M
# Deteksi wajah berhasil: M0064.png di folder M
# Deteksi wajah berhasil: M0065.png di folder M
# Deteksi wajah berhasil: M0066.png di folder M
# Deteksi wajah berhasil: M0067.png di folder M
# Deteksi wajah berhasil: M0070.png di folder M
# Deteksi wajah berhasil: M0072.png di folder M
# Deteksi wajah berhasil: M0074.png di folder M
# Deteksi wajah berhasil: M0076.png di folder M
# Deteksi wajah berhasil: M0077.png di folder M
# Deteksi wajah berhasil: M0078.png di folder M
# Deteksi wajah berhasil: M0079.png di folder M
# Deteksi wajah berhasil: M0080.png di folder M
# Deteksi wajah berhasil: M0082.png di folder M
# Deteksi wajah berhasil: M0083.png di folder M
# Deteksi wajah berhasil: M0085.png di folder M
# Deteksi wajah berhasil: M0086.png di folder M
# Deteksi wajah berhasil: M0088.png di folder M
# Deteksi wajah berhasil: M0089.png di folder M
# Deteksi wajah berhasil: M0090.png di folder M
# Deteksi wajah berhasil: M0091.png di folder M
# Deteksi wajah berhasil: M0092.png di folder M
# Deteksi wajah berhasil: M0093.png di folder M
# Deteksi wajah berhasil: M0094.png di folder M
# Deteksi wajah berhasil: M0095.png di folder M
# Deteksi wajah berhasil: M0103.png di folder M
# Deteksi wajah berhasil: M0104.png di folder M
# Deteksi wajah berhasil: M0105.png di folder M
# Deteksi wajah berhasil: M0106.png di folder M
# Deteksi wajah berhasil: M0107.png di folder M
# Deteksi wajah berhasil: M0108.png di folder M
# Deteksi wajah berhasil: M0109.png di folder M
# Deteksi wajah berhasil: M0112.png di folder M
# Deteksi wajah berhasil: M0113.png di folder M
# Deteksi wajah berhasil: M0115.png di folder M
# Deteksi wajah berhasil: M0116.png di folder M
# Deteksi wajah berhasil: M0118.png di folder M
# Deteksi wajah berhasil: M0119.png di folder M
# Deteksi wajah berhasil: M0120.png di folder M
# Deteksi wajah berhasil: M0121.png di folder M
# Deteksi wajah berhasil: M0122.png di folder M
# Deteksi wajah berhasil: M0123.png di folder M
# Deteksi wajah berhasil: M0124.png di folder M
# Deteksi wajah berhasil: M0125.png di folder M
# Deteksi wajah berhasil: M0126.png di folder M
# Deteksi wajah berhasil: M0127.png di folder M
# Deteksi wajah berhasil: M0128.png di folder M
# Deteksi wajah berhasil: M0129.png di folder M
# Deteksi wajah berhasil: M0131.png di folder M
# Deteksi wajah berhasil: M0132.png di folder M
# Deteksi wajah berhasil: M0133.png di folder M
# Deteksi wajah berhasil: M0134.png di folder M
# Deteksi wajah berhasil: M0137.png di folder M
# Deteksi wajah berhasil: M0138.png di folder M
# Deteksi wajah berhasil: M0139.png di folder M
# Deteksi wajah berhasil: M0140.png di folder M
# Deteksi wajah berhasil: M0141.png di folder M
# Deteksi wajah berhasil: M0142.png di folder M
# Deteksi wajah berhasil: M0145.png di folder M
# Deteksi wajah berhasil: M0146.png di folder M
# Deteksi wajah berhasil: M0147.png di folder M
# Deteksi wajah berhasil: M0152.png di folder M
# Deteksi wajah berhasil: M0153.png di folder M
# Deteksi wajah berhasil: M0156.png di folder M
# Deteksi wajah berhasil: M0158.png di folder M
# Deteksi wajah berhasil: M0159.png di folder M
# Deteksi wajah berhasil: M0160.png di folder M
# Deteksi wajah berhasil: M0161.png di folder M
# Deteksi wajah berhasil: M0163.png di folder M
# Deteksi wajah berhasil: M0165.png di folder M
# Deteksi wajah berhasil: M0166.png di folder M
# Deteksi wajah berhasil: M0167.png di folder M
# Deteksi wajah berhasil: M0169.png di folder M
# Deteksi wajah berhasil: M0170.png di folder M
# Deteksi wajah berhasil: M0173.png di folder M
# Deteksi wajah berhasil: M0174.png di folder M
# Deteksi wajah berhasil: M0175.png di folder M
# Deteksi wajah berhasil: M0176.png di folder M
# Deteksi wajah berhasil: M0177.png di folder M
# Deteksi wajah berhasil: M0178.png di folder M
# Deteksi wajah berhasil: M0179.png di folder M
# Deteksi wajah berhasil: M0181.png di folder M
# Deteksi wajah berhasil: M0182.png di folder M
# Deteksi wajah berhasil: M0185.png di folder M
# Deteksi wajah berhasil: M0186.png di folder M
# Deteksi wajah berhasil: M0187.png di folder M
# Deteksi wajah berhasil: M0190.png di folder M
# Deteksi wajah berhasil: M0193.png di folder M
# Deteksi wajah berhasil: M0194.png di folder M
# Deteksi wajah berhasil: M0196.png di folder M
# Deteksi wajah berhasil: M0197.png di folder M
# Deteksi wajah berhasil: M0200.png di folder M
# Deteksi wajah berhasil: M0201.png di folder M
# Deteksi wajah berhasil: M0202.png di folder M
# Deteksi wajah berhasil: M0203.png di folder M
# Deteksi wajah berhasil: M0204.png di folder M
# Deteksi wajah berhasil: M0205.png di folder M
# Deteksi wajah berhasil: M0206.png di folder M
# Deteksi wajah berhasil: M0207.png di folder M
# Deteksi wajah berhasil: M0209.png di folder M
# Deteksi wajah berhasil: M0210.png di folder M
# Deteksi wajah berhasil: M0211.png di folder M
# Deteksi wajah berhasil: M0212.png di folder M
# Deteksi wajah berhasil: M0214.png di folder M
# Deteksi wajah berhasil: M0215.png di folder M
# Deteksi wajah berhasil: M0216.png di folder M
# Deteksi wajah berhasil: M0219.png di folder M
# Deteksi wajah berhasil: M0222.png di folder M
# Deteksi wajah berhasil: M0226.png di folder M
# Deteksi wajah berhasil: M0229.png di folder M
# Deteksi wajah berhasil: M0230.png di folder M
# Deteksi wajah berhasil: M0231.png di folder M
# Deteksi wajah berhasil: M0233.png di folder M
# Deteksi wajah berhasil: M0236.png di folder M
# Deteksi wajah berhasil: M0238.png di folder M
# Deteksi wajah berhasil: M0239.png di folder M
# Deteksi wajah berhasil: M0240.png di folder M
# Deteksi wajah berhasil: M0241.png di folder M
# Deteksi wajah berhasil: M0242.png di folder M
# Deteksi wajah berhasil: M0243.png di folder M
# Deteksi wajah berhasil: M0244.png di folder M
# Deteksi wajah berhasil: M0245.png di folder M
# Deteksi wajah berhasil: M0247.png di folder M
# Deteksi wajah berhasil: M0248.png di folder M
# Deteksi wajah berhasil: M0250.png di folder M
# Deteksi wajah berhasil: M0251.png di folder M
# Deteksi wajah berhasil: M0252.png di folder M
# Deteksi wajah berhasil: M0254.png di folder M
# Deteksi wajah berhasil: M0255.png di folder M
# Deteksi wajah berhasil: M0256.png di folder M
# Deteksi wajah berhasil: M0257.png di folder M
# Deteksi wajah berhasil: M0258.png di folder M
# Deteksi wajah berhasil: M0259.png di folder M
# Deteksi wajah berhasil: M0260.png di folder M
# Deteksi wajah berhasil: M0261.png di folder M
# Deteksi wajah berhasil: M0262.png di folder M
# Deteksi wajah berhasil: M0263.png di folder M
# Deteksi wajah berhasil: M0265.png di folder M
# Deteksi wajah berhasil: M0268.png di folder M
# Deteksi wajah berhasil: M0269.png di folder M
# Deteksi wajah berhasil: M0270.png di folder M
# Deteksi wajah berhasil: M0271.png di folder M
# Deteksi wajah berhasil: M0272.png di folder M
# Deteksi wajah berhasil: M0273.png di folder M
# Deteksi wajah berhasil: M0274.png di folder M
# Deteksi wajah berhasil: M0275.png di folder M
# Deteksi wajah berhasil: M0276.png di folder M
# Deteksi wajah berhasil: M0277.png di folder M
# Deteksi wajah berhasil: M0278.png di folder M
# Deteksi wajah berhasil: M0279.png di folder M
# Deteksi wajah berhasil: M0280.png di folder M
# Deteksi wajah berhasil: M0282.png di folder M
# Deteksi wajah berhasil: M0285.png di folder M
# Deteksi wajah berhasil: M0286.png di folder M
# Deteksi wajah berhasil: M0287.png di folder M
# Deteksi wajah berhasil: M0288.png di folder M
# Deteksi wajah berhasil: M0289.png di folder M
# Deteksi wajah berhasil: M0291.png di folder M
# Deteksi wajah berhasil: M0292.png di folder M
# Deteksi wajah berhasil: M0293.png di folder M
# Deteksi wajah berhasil: M0295.png di folder M
# Deteksi wajah berhasil: M0297.png di folder M
# Deteksi wajah berhasil: M0300.png di folder M
# Deteksi wajah berhasil: M0301.png di folder M
# Deteksi wajah berhasil: M0303.png di folder M
# Deteksi wajah berhasil: M0304.png di folder M
# Deteksi wajah berhasil: M0305.png di folder M
# Deteksi wajah berhasil: M0306.png di folder M
# Deteksi wajah berhasil: M0307.png di folder M
# Deteksi wajah berhasil: M0308.png di folder M
# Deteksi wajah berhasil: M0309.png di folder M
# Deteksi wajah berhasil: M0310.png di folder M
# Deteksi wajah berhasil: M0322.png di folder M
# Deteksi wajah berhasil: M0324.png di folder M
# Deteksi wajah berhasil: M0325.png di folder M
# Deteksi wajah berhasil: M0327.png di folder M
# Deteksi wajah berhasil: M0328.png di folder M
# Deteksi wajah berhasil: M0329.png di folder M
# Deteksi wajah berhasil: M0330.png di folder M
# Deteksi wajah berhasil: M0331.png di folder M
# Deteksi wajah berhasil: M0332.png di folder M
# Deteksi wajah berhasil: M0333.png di folder M
# Deteksi wajah berhasil: M0336.png di folder M
# Deteksi wajah berhasil: M0337.png di folder M
# Deteksi wajah berhasil: M0340.png di folder M
# Deteksi wajah berhasil: M0341.png di folder M
# Deteksi wajah berhasil: M0342.png di folder M
# Deteksi wajah berhasil: M0344.png di folder M
# Deteksi wajah berhasil: M0345.png di folder M
# Deteksi wajah berhasil: M0347.png di folder M
# Deteksi wajah berhasil: M0348.png di folder M
# Deteksi wajah berhasil: M0349.png di folder M
# Deteksi wajah berhasil: M0350.png di folder M
# Deteksi wajah berhasil: M0351.png di folder M
# Deteksi wajah berhasil: M0352.png di folder M
# Deteksi wajah berhasil: M0353.png di folder M
# Deteksi wajah berhasil: M0354.png di folder M
# Deteksi wajah berhasil: M0355.png di folder M
# Deteksi wajah berhasil: M0356.png di folder M
# Deteksi wajah berhasil: M0357.png di folder M
# Deteksi wajah berhasil: M0359.png di folder M
# Deteksi wajah berhasil: M0360.png di folder M
# Deteksi wajah berhasil: M0361.png di folder M
# Deteksi wajah berhasil: M0362.png di folder M
# Deteksi wajah berhasil: M0365.png di folder M
# Deteksi wajah berhasil: M0367.png di folder M
# Deteksi wajah berhasil: M0369.png di folder M
# Deteksi wajah berhasil: M0370.png di folder M
# Deteksi wajah berhasil: M0372.png di folder M
# Deteksi wajah berhasil: M0373.png di folder M
# Deteksi wajah berhasil: M0374.png di folder M
# Deteksi wajah berhasil: M0375.png di folder M
# Deteksi wajah berhasil: M0377.png di folder M
# Deteksi wajah berhasil: M0378.png di folder M
# Deteksi wajah berhasil: M0380.png di folder M
# Deteksi wajah berhasil: M0381.png di folder M
# Deteksi wajah berhasil: M0382.png di folder M
# Deteksi wajah berhasil: M0383.png di folder M
# Deteksi wajah berhasil: M0385.png di folder M
# Deteksi wajah berhasil: M0387.png di folder M
# Deteksi wajah berhasil: M0388.png di folder M
# Deteksi wajah berhasil: M0389.png di folder M
# Deteksi wajah berhasil: M0392.png di folder M
# Deteksi wajah berhasil: M0394.png di folder M
# Deteksi wajah berhasil: M0398.png di folder M
# Deteksi wajah berhasil: M0400.png di folder M
# Deteksi wajah berhasil: M0401.png di folder M
# Deteksi wajah berhasil: M0402.png di folder M
# Deteksi wajah berhasil: M0405.png di folder M
# Deteksi wajah berhasil: M0409.png di folder M
# Deteksi wajah berhasil: M0410.png di folder M
# Deteksi wajah berhasil: M0411.png di folder M
# Deteksi wajah berhasil: M0412.png di folder M
# Deteksi wajah berhasil: M0413.png di folder M
# Deteksi wajah berhasil: M0414.png di folder M
# Deteksi wajah berhasil: M0416.png di folder M
# Deteksi wajah berhasil: M0418.png di folder M
# Deteksi wajah berhasil: M0421.png di folder M
# Deteksi wajah berhasil: M0422.png di folder M
# Deteksi wajah berhasil: M0423.png di folder M
# Deteksi wajah berhasil: M0424.png di folder M
# Deteksi wajah berhasil: M0428.png di folder M
# Deteksi wajah berhasil: M0429.png di folder M
# Deteksi wajah berhasil: M0430.png di folder M
# Deteksi wajah berhasil: M0434.png di folder M
# Deteksi wajah berhasil: M0435.png di folder M
# Deteksi wajah berhasil: M0436.png di folder M
# Deteksi wajah berhasil: M0437.png di folder M
# Deteksi wajah berhasil: M0439.png di folder M
# Deteksi wajah berhasil: M0440.png di folder M
# Deteksi wajah berhasil: M0441.png di folder M
# Deteksi wajah berhasil: M0442.png di folder M
# Deteksi wajah berhasil: M0443.png di folder M
# Deteksi wajah berhasil: M0445.png di folder M
# Deteksi wajah berhasil: M0446.png di folder M
# Deteksi wajah berhasil: M0448.png di folder M
# Deteksi wajah berhasil: M0449.png di folder M
# Deteksi wajah berhasil: M0451.png di folder M
# Deteksi wajah berhasil: M0452.png di folder M
# Deteksi wajah berhasil: M0453.png di folder M
# Deteksi wajah berhasil: M0455.png di folder M
# Deteksi wajah berhasil: M0456.png di folder M
# Deteksi wajah berhasil: M0459.png di folder M
# Deteksi wajah berhasil: M0460.png di folder M
# Deteksi wajah berhasil: M0461.png di folder M
# Deteksi wajah berhasil: M0462.png di folder M
# Deteksi wajah berhasil: M0464.png di folder M
# Deteksi wajah berhasil: M0466.png di folder M
# Deteksi wajah berhasil: M0467.png di folder M
# Deteksi wajah berhasil: M0468.png di folder M
# Deteksi wajah berhasil: M0469.png di folder M
# Deteksi wajah berhasil: M0470.png di folder M
# Deteksi wajah berhasil: M0472.png di folder M
# Deteksi wajah berhasil: M0473.png di folder M
# Deteksi wajah berhasil: M0474.png di folder M
# Deteksi wajah berhasil: M0476.png di folder M
# Deteksi wajah berhasil: M0477.png di folder M
# Deteksi wajah berhasil: M0478.png di folder M
# Deteksi wajah berhasil: M0479.png di folder M
# Deteksi wajah berhasil: M0480.png di folder M
# Deteksi wajah berhasil: M0481.png di folder M
# Deteksi wajah berhasil: M0482.png di folder M
# Deteksi wajah berhasil: M0484.png di folder M
# Deteksi wajah berhasil: M0486.png di folder M
# Deteksi wajah berhasil: M0489.png di folder M
# Deteksi wajah berhasil: M0490.png di folder M
# Deteksi wajah berhasil: M0492.png di folder M
# Deteksi wajah berhasil: M0495.png di folder M
# Deteksi wajah berhasil: M0496.png di folder M
# Deteksi wajah berhasil: M0497.png di folder M
# Deteksi wajah berhasil: M0498.png di folder M
# Deteksi wajah berhasil: M0499.png di folder M
# Deteksi wajah berhasil: M0500.png di folder M
# Deteksi wajah berhasil: M0502.png di folder M
# Deteksi wajah berhasil: M0503.png di folder M
# Deteksi wajah berhasil: M0506.png di folder M
# Deteksi wajah berhasil: M0507.png di folder M
# Deteksi wajah berhasil: M0508.png di folder M
# Deteksi wajah berhasil: M0510.png di folder M
# Deteksi wajah berhasil: M0513.png di folder M
# Deteksi wajah berhasil: M0514.png di folder M
# Deteksi wajah berhasil: M0515.png di folder M
# Deteksi wajah berhasil: M0516.png di folder M
# Deteksi wajah berhasil: M0517.png di folder M
# Deteksi wajah berhasil: M0518.png di folder M
# Deteksi wajah berhasil: M0519.png di folder M
# Deteksi wajah berhasil: M0520.png di folder M
# Deteksi wajah berhasil: M0522.png di folder M
# Deteksi wajah berhasil: M0523.png di folder M
# Deteksi wajah berhasil: M0524.png di folder M
# Deteksi wajah berhasil: M0526.png di folder M
# Deteksi wajah berhasil: M0528.png di folder M
# Deteksi wajah berhasil: M0529.png di folder M
# Deteksi wajah berhasil: M0530.png di folder M
# Deteksi wajah berhasil: M0531.png di folder M
# Deteksi wajah berhasil: M0533.png di folder M
# Deteksi wajah berhasil: M0535.png di folder M
# Deteksi wajah berhasil: M0537.png di folder M
# Deteksi wajah berhasil: M0538.png di folder M
# Deteksi wajah berhasil: M0541.png di folder M
# Deteksi wajah berhasil: M0543.png di folder M
# Deteksi wajah berhasil: M0544.png di folder M
# Deteksi wajah berhasil: M0545.png di folder M
# Deteksi wajah berhasil: M0547.png di folder M
# Deteksi wajah berhasil: M0552.png di folder M
# Deteksi wajah berhasil: M0553.png di folder M
# Deteksi wajah berhasil: M0554.png di folder M
# Deteksi wajah berhasil: M0555.png di folder M
# Deteksi wajah berhasil: M0557.png di folder M
# Deteksi wajah berhasil: M0558.png di folder M
# Deteksi wajah berhasil: M0559.png di folder M
# Deteksi wajah berhasil: M0560.png di folder M
# Deteksi wajah berhasil: M0564.png di folder M
# Deteksi wajah berhasil: M0565.png di folder M
# Deteksi wajah berhasil: M0566.png di folder M
# Deteksi wajah berhasil: M0567.png di folder M
# Deteksi wajah berhasil: M0568.png di folder M
# Deteksi wajah berhasil: M0569.png di folder M
# Deteksi wajah berhasil: M0570.png di folder M
# Deteksi wajah berhasil: M0571.png di folder M
# Deteksi wajah berhasil: M0572.png di folder M
# Deteksi wajah berhasil: M0573.png di folder M
# Deteksi wajah berhasil: M0575.png di folder M
# Deteksi wajah berhasil: M0576.png di folder M
# Deteksi wajah berhasil: M0577.png di folder M
# Deteksi wajah berhasil: M0578.png di folder M
# Deteksi wajah berhasil: M0579.png di folder M
# Deteksi wajah berhasil: M0580.png di folder M
# Deteksi wajah berhasil: M0581.png di folder M
# Deteksi wajah berhasil: M0584.png di folder M
# Deteksi wajah berhasil: M0585.png di folder M
# Deteksi wajah berhasil: M0586.png di folder M
# Deteksi wajah berhasil: M0588.png di folder M
# Deteksi wajah berhasil: M0589.png di folder M
# Deteksi wajah berhasil: M0590.png di folder M
# Deteksi wajah berhasil: M0591.png di folder M
# Deteksi wajah berhasil: M0592.png di folder M
# Deteksi wajah berhasil: M0593.png di folder M
# Deteksi wajah berhasil: M0594.png di folder M
# Deteksi wajah berhasil: M0595.png di folder M
# Deteksi wajah berhasil: M0596.png di folder M
# Deteksi wajah berhasil: M0598.png di folder M
# Deteksi wajah berhasil: M0599.png di folder M
# Deteksi wajah berhasil: M0600.png di folder M
# Deteksi wajah berhasil: M0601.png di folder M
# Deteksi wajah berhasil: M0602.png di folder M
# Deteksi wajah berhasil: M0603.png di folder M
# Deteksi wajah berhasil: M0604.png di folder M
# Deteksi wajah berhasil: M0605.png di folder M
# Deteksi wajah berhasil: M0608.png di folder M
# Deteksi wajah berhasil: M0609.png di folder M
# Deteksi wajah berhasil: M0610.png di folder M
# Deteksi wajah berhasil: M0611.png di folder M
# Deteksi wajah berhasil: M0613.png di folder M
# Deteksi wajah berhasil: M0615.png di folder M
# Deteksi wajah berhasil: M0616.png di folder M
# Deteksi wajah berhasil: M0617.png di folder M
# Deteksi wajah berhasil: M0618.png di folder M
# Deteksi wajah berhasil: M0619.png di folder M
# Deteksi wajah berhasil: M0620.png di folder M
# Deteksi wajah berhasil: M0622.png di folder M
# Deteksi wajah berhasil: M0623.png di folder M
# Deteksi wajah berhasil: M0625.png di folder M
# Deteksi wajah berhasil: M0626.png di folder M
# Deteksi wajah berhasil: M0627.png di folder M
# Deteksi wajah berhasil: M0629.png di folder M
# Deteksi wajah berhasil: M0634.png di folder M
# Deteksi wajah berhasil: M0635.png di folder M
# Deteksi wajah berhasil: M0636.png di folder M
# Deteksi wajah berhasil: M0637.png di folder M
# Deteksi wajah berhasil: M0638.png di folder M
# Deteksi wajah berhasil: M0639.png di folder M
# Deteksi wajah berhasil: M0640.png di folder M
# Deteksi wajah berhasil: M0641.png di folder M
# Deteksi wajah berhasil: M0642.png di folder M
# Deteksi wajah berhasil: M0643.png di folder M
# Deteksi wajah berhasil: M0644.png di folder M
# Deteksi wajah berhasil: M0649.png di folder M
# Deteksi wajah berhasil: M0651.png di folder M
# Deteksi wajah berhasil: M0652.png di folder M
# Deteksi wajah berhasil: M0654.png di folder M
# Deteksi wajah berhasil: M0657.png di folder M
# Deteksi wajah berhasil: M0658.png di folder M
# Deteksi wajah berhasil: M0660.png di folder M
# Deteksi wajah berhasil: M0661.png di folder M
# Deteksi wajah berhasil: M0662.png di folder M
# Deteksi wajah berhasil: M0663.png di folder M
# Deteksi wajah berhasil: M0664.png di folder M
# Deteksi wajah berhasil: M0665.png di folder M
# Deteksi wajah berhasil: M0666.png di folder M
# Deteksi wajah berhasil: M0667.png di folder M
# Deteksi wajah berhasil: M0668.png di folder M
# Deteksi wajah berhasil: M0669.png di folder M
# Deteksi wajah berhasil: M0672.png di folder M
# Deteksi wajah berhasil: M0673.png di folder M
# Deteksi wajah berhasil: M0675.png di folder M
# Deteksi wajah berhasil: M0676.png di folder M
# Deteksi wajah berhasil: M0678.png di folder M
# Deteksi wajah berhasil: M0680.png di folder M
# Deteksi wajah berhasil: M0681.png di folder M
# Deteksi wajah berhasil: M0682.png di folder M
# Deteksi wajah berhasil: M0683.png di folder M
# Deteksi wajah berhasil: M0687.png di folder M
# Deteksi wajah berhasil: M0688.png di folder M
# Deteksi wajah berhasil: M0689.png di folder M
# Deteksi wajah berhasil: M0691.png di folder M
# Deteksi wajah berhasil: M0693.png di folder M
# Deteksi wajah berhasil: M0694.png di folder M
# Deteksi wajah berhasil: M0695.png di folder M
# Deteksi wajah berhasil: M0696.png di folder M
# Deteksi wajah berhasil: M0697.png di folder M
# Deteksi wajah berhasil: M0698.png di folder M
# Deteksi wajah berhasil: M0699.png di folder M
# Deteksi wajah berhasil: M0700.png di folder M
# Deteksi wajah berhasil: M0703.png di folder M
# Deteksi wajah berhasil: M0704.png di folder M
# Deteksi wajah berhasil: M0706.png di folder M
# Deteksi wajah berhasil: M0707.png di folder M
# Deteksi wajah berhasil: M0708.png di folder M
# Deteksi wajah berhasil: M0709.png di folder M
# Deteksi wajah berhasil: M0710.png di folder M
# Deteksi wajah berhasil: M0712.png di folder M
# Deteksi wajah berhasil: M0713.png di folder M
# Deteksi wajah berhasil: M0714.png di folder M
# Deteksi wajah berhasil: M0715.png di folder M
# Deteksi wajah berhasil: M0716.png di folder M
# Deteksi wajah berhasil: M0718.png di folder M
# Deteksi wajah berhasil: M0721.png di folder M
# Deteksi wajah berhasil: M0722.png di folder M
# Deteksi wajah berhasil: M0724.png di folder M
# Deteksi wajah berhasil: M0726.png di folder M
# Deteksi wajah berhasil: M0728.png di folder M
# Deteksi wajah berhasil: M0732.png di folder M
# Deteksi wajah berhasil: M0734.png di folder M
# Deteksi wajah berhasil: M0736.png di folder M
# Deteksi wajah berhasil: M0737.png di folder M
# Deteksi wajah berhasil: M0738.png di folder M
# Deteksi wajah berhasil: M0739.png di folder M
# Deteksi wajah berhasil: M0740.png di folder M
# Deteksi wajah berhasil: M0741.png di folder M
# Deteksi wajah berhasil: M0744.png di folder M
# Deteksi wajah berhasil: M0745.png di folder M
# Deteksi wajah berhasil: M0747.png di folder M
# Deteksi wajah berhasil: M0750.png di folder M
# Deteksi wajah berhasil: M0751.png di folder M
# Deteksi wajah berhasil: M0752.png di folder M
# Deteksi wajah berhasil: M0753.png di folder M
# Deteksi wajah berhasil: M0754.png di folder M
# Deteksi wajah berhasil: M0756.png di folder M
# Deteksi wajah berhasil: M0758.png di folder M
# Deteksi wajah berhasil: M0760.png di folder M
# Deteksi wajah berhasil: M0761.png di folder M
# Deteksi wajah berhasil: M0762.png di folder M
# Deteksi wajah berhasil: M0763.png di folder M
# Deteksi wajah berhasil: M0765.png di folder M
# Deteksi wajah berhasil: M0767.png di folder M
# Deteksi wajah berhasil: M0768.png di folder M
# Deteksi wajah berhasil: M0769.png di folder M
# Deteksi wajah berhasil: M0771.png di folder M
# Deteksi wajah berhasil: M0772.png di folder M
# Deteksi wajah berhasil: M0773.png di folder M
# Deteksi wajah berhasil: M0777.png di folder M
# Deteksi wajah berhasil: M0778.png di folder M
# Deteksi wajah berhasil: M0779.png di folder M
# Deteksi wajah berhasil: M0781.png di folder M
# Deteksi wajah berhasil: M0783.png di folder M
# Deteksi wajah berhasil: M0790.png di folder M
# Deteksi wajah berhasil: M0791.png di folder M
# Deteksi wajah berhasil: M0792.png di folder M
# Deteksi wajah berhasil: M0795.png di folder M
# Deteksi wajah berhasil: M0796.png di folder M
# Deteksi wajah berhasil: M0798.png di folder M
# Deteksi wajah berhasil: M0800.png di folder M
# Deteksi wajah berhasil: M0806.png di folder M
# Deteksi wajah berhasil: M0807.png di folder M
# Deteksi wajah berhasil: M0808.png di folder M
# Deteksi wajah berhasil: M0809.png di folder M
# Deteksi wajah berhasil: M0811.png di folder M
# Deteksi wajah berhasil: M0817.png di folder M
# Deteksi wajah berhasil: M0818.png di folder M
# Deteksi wajah berhasil: M0819.png di folder M
# Deteksi wajah berhasil: W0458.png di folder W
# Deteksi wajah berhasil: W0459.png di folder W
# Deteksi wajah berhasil: W0460.png di folder W
# Deteksi wajah berhasil: W0464.png di folder W
# Deteksi wajah berhasil: W0468.png di folder W
# Deteksi wajah berhasil: W0475.png di folder W
# Deteksi wajah berhasil: W0477.png di folder W
# Deteksi wajah berhasil: W0479.png di folder W
# Deteksi wajah berhasil: X0002.png di folder X
# Deteksi wajah berhasil: X0003.png di folder X
# Deteksi wajah berhasil: X0004.png di folder X
# Deteksi wajah berhasil: X0006.png di folder X
# Deteksi wajah berhasil: X0007.png di folder X
# Deteksi wajah berhasil: X0009.png di folder X
# Deteksi wajah berhasil: X0010.png di folder X
# Deteksi wajah berhasil: X0011.png di folder X
# Deteksi wajah berhasil: X0012.png di folder X
# Deteksi wajah berhasil: X0015.png di folder X
# Deteksi wajah berhasil: X0016.png di folder X
# Deteksi wajah berhasil: X0017.png di folder X
# Deteksi wajah berhasil: X0020.png di folder X
# Deteksi wajah berhasil: X0021.png di folder X
# Deteksi wajah berhasil: X0022.png di folder X
# Deteksi wajah berhasil: X0024.png di folder X
# Deteksi wajah berhasil: X0025.png di folder X
# Deteksi wajah berhasil: X0026.png di folder X
# Deteksi wajah berhasil: X0029.png di folder X
# Deteksi wajah berhasil: X0030.png di folder X
# Deteksi wajah berhasil: X0032.png di folder X
# Deteksi wajah berhasil: X0034.png di folder X
# Deteksi wajah berhasil: X0035.png di folder X
# Deteksi wajah berhasil: X0036.png di folder X
# Deteksi wajah berhasil: X0037.png di folder X
# Deteksi wajah berhasil: X0039.png di folder X
# Deteksi wajah berhasil: X0042.png di folder X
# Deteksi wajah berhasil: X0043.png di folder X
# Deteksi wajah berhasil: X0044.png di folder X
# Deteksi wajah berhasil: X0045.png di folder X
# Deteksi wajah berhasil: X0046.png di folder X
# Deteksi wajah berhasil: X0047.png di folder X
# Deteksi wajah berhasil: X0048.png di folder X
# Deteksi wajah berhasil: X0049.png di folder X
# Deteksi wajah berhasil: X0051.png di folder X
# Deteksi wajah berhasil: X0052.png di folder X
# Deteksi wajah berhasil: X0053.png di folder X
# Deteksi wajah berhasil: X0054.png di folder X
# Deteksi wajah berhasil: X0055.png di folder X
# Deteksi wajah berhasil: X0056.png di folder X
# Deteksi wajah berhasil: X0057.png di folder X
# Deteksi wajah berhasil: X0059.png di folder X
# Deteksi wajah berhasil: X0060.png di folder X
# Deteksi wajah berhasil: X0061.png di folder X
# Deteksi wajah berhasil: X0063.png di folder X
# Deteksi wajah berhasil: X0064.png di folder X
# Deteksi wajah berhasil: X0065.png di folder X
# Deteksi wajah berhasil: X0066.png di folder X
# Deteksi wajah berhasil: X0069.png di folder X
# Deteksi wajah berhasil: X0070.png di folder X
# Deteksi wajah berhasil: X0071.png di folder X
# Deteksi wajah berhasil: X0073.png di folder X
# Deteksi wajah berhasil: X0074.png di folder X
# Deteksi wajah berhasil: X0075.png di folder X
# Deteksi wajah berhasil: X0077.png di folder X
# Deteksi wajah berhasil: X0078.png di folder X
# Deteksi wajah berhasil: X0079.png di folder X
# Deteksi wajah berhasil: X0081.png di folder X
# Deteksi wajah berhasil: X0082.png di folder X
# Deteksi wajah berhasil: X0085.png di folder X
# Deteksi wajah berhasil: X0086.png di folder X
# Deteksi wajah berhasil: X0087.png di folder X
# Deteksi wajah berhasil: X0088.png di folder X
# Deteksi wajah berhasil: X0091.png di folder X
# Deteksi wajah berhasil: X0092.png di folder X
# Deteksi wajah berhasil: X0093.png di folder X
# Deteksi wajah berhasil: X0096.png di folder X
# Deteksi wajah berhasil: X0097.png di folder X
# Deteksi wajah berhasil: X0098.png di folder X
# Deteksi wajah berhasil: X0099.png di folder X
# Deteksi wajah berhasil: X0100.png di folder X
# Deteksi wajah berhasil: X0101.png di folder X
# Deteksi wajah berhasil: X0102.png di folder X
# Deteksi wajah berhasil: X0104.png di folder X
# Deteksi wajah berhasil: X0105.png di folder X
# Deteksi wajah berhasil: X0106.png di folder X
# Deteksi wajah berhasil: X0107.png di folder X
# Deteksi wajah berhasil: X0108.png di folder X
# Deteksi wajah berhasil: X0110.png di folder X
# Deteksi wajah berhasil: X0111.png di folder X
# Deteksi wajah berhasil: X0113.png di folder X
# Deteksi wajah berhasil: X0114.png di folder X
# Deteksi wajah berhasil: X0115.png di folder X
# Deteksi wajah berhasil: X0116.png di folder X
# Deteksi wajah berhasil: X0117.png di folder X
# Deteksi wajah berhasil: X0118.png di folder X
# Deteksi wajah berhasil: X0119.png di folder X
# Deteksi wajah berhasil: X0120.png di folder X
# Deteksi wajah berhasil: X0121.png di folder X
# Deteksi wajah berhasil: X0122.png di folder X
# Deteksi wajah berhasil: X0123.png di folder X
# Deteksi wajah berhasil: X0125.png di folder X
# Deteksi wajah berhasil: X0126.png di folder X
# Deteksi wajah berhasil: X0127.png di folder X
# Deteksi wajah berhasil: X0129.png di folder X
# Deteksi wajah berhasil: X0130.png di folder X
# Deteksi wajah berhasil: X0132.png di folder X
# Deteksi wajah berhasil: X0133.png di folder X
# Deteksi wajah berhasil: X0134.png di folder X
# Deteksi wajah berhasil: X0135.png di folder X
# Deteksi wajah berhasil: X0136.png di folder X
# Deteksi wajah berhasil: X0137.png di folder X
# Deteksi wajah berhasil: X0138.png di folder X
# Deteksi wajah berhasil: X0139.png di folder X
# Deteksi wajah berhasil: X0140.png di folder X
# Deteksi wajah berhasil: X0141.png di folder X
# Deteksi wajah berhasil: X0142.png di folder X
# Deteksi wajah berhasil: X0143.png di folder X
# Deteksi wajah berhasil: X0144.png di folder X
# Deteksi wajah berhasil: X0145.png di folder X
# Deteksi wajah berhasil: X0146.png di folder X
# Deteksi wajah berhasil: X0147.png di folder X
# Deteksi wajah berhasil: X0148.png di folder X
# Deteksi wajah berhasil: X0150.png di folder X
# Deteksi wajah berhasil: X0151.png di folder X
# Deteksi wajah berhasil: X0153.png di folder X
# Deteksi wajah berhasil: X0154.png di folder X
# Deteksi wajah berhasil: X0155.png di folder X
# Deteksi wajah berhasil: X0156.png di folder X
# Deteksi wajah berhasil: X0157.png di folder X
# Deteksi wajah berhasil: X0158.png di folder X
# Deteksi wajah berhasil: X0159.png di folder X
# Deteksi wajah berhasil: X0160.png di folder X
# Deteksi wajah berhasil: X0161.png di folder X
# Deteksi wajah berhasil: X0162.png di folder X
# Deteksi wajah berhasil: X0163.png di folder X
# Deteksi wajah berhasil: X0164.png di folder X
# Deteksi wajah berhasil: X0165.png di folder X
# Deteksi wajah berhasil: X0166.png di folder X
# Deteksi wajah berhasil: X0168.png di folder X
# Deteksi wajah berhasil: X0169.png di folder X
# Deteksi wajah berhasil: X0170.png di folder X
# Deteksi wajah berhasil: X0171.png di folder X
# Deteksi wajah berhasil: X0172.png di folder X
# Deteksi wajah berhasil: X0173.png di folder X
# Deteksi wajah berhasil: X0175.png di folder X
# Deteksi wajah berhasil: X0176.png di folder X
# Deteksi wajah berhasil: X0179.png di folder X
# Deteksi wajah berhasil: X0180.png di folder X
# Deteksi wajah berhasil: X0182.png di folder X
# Deteksi wajah berhasil: X0186.png di folder X
# Deteksi wajah berhasil: X0187.png di folder X
# Deteksi wajah berhasil: X0188.png di folder X
# Deteksi wajah berhasil: X0189.png di folder X
# Deteksi wajah berhasil: X0191.png di folder X
# Deteksi wajah berhasil: X0193.png di folder X
# Deteksi wajah berhasil: X0194.png di folder X
# Deteksi wajah berhasil: X0195.png di folder X
# Deteksi wajah berhasil: X0196.png di folder X
# Deteksi wajah berhasil: X0197.png di folder X
# Deteksi wajah berhasil: X0198.png di folder X
# Deteksi wajah berhasil: X0199.png di folder X
# Deteksi wajah berhasil: X0201.png di folder X
# Deteksi wajah berhasil: X0202.png di folder X
# Deteksi wajah berhasil: X0203.png di folder X
# Deteksi wajah berhasil: X0204.png di folder X
# Deteksi wajah berhasil: X0205.png di folder X
# Deteksi wajah berhasil: X0207.png di folder X
# Deteksi wajah berhasil: X0209.png di folder X
# Deteksi wajah berhasil: X0210.png di folder X
# Deteksi wajah berhasil: X0211.png di folder X
# Deteksi wajah berhasil: X0212.png di folder X
# Deteksi wajah berhasil: X0214.png di folder X
# Deteksi wajah berhasil: X0215.png di folder X
# Deteksi wajah berhasil: X0217.png di folder X
# Deteksi wajah berhasil: X0218.png di folder X
# Deteksi wajah berhasil: X0219.png di folder X
# Deteksi wajah berhasil: X0220.png di folder X
# Deteksi wajah berhasil: X0221.png di folder X
# Deteksi wajah berhasil: X0222.png di folder X
# Deteksi wajah berhasil: X0223.png di folder X
# Deteksi wajah berhasil: X0224.png di folder X
# Deteksi wajah berhasil: X0225.png di folder X
# Deteksi wajah berhasil: X0227.png di folder X
# Deteksi wajah berhasil: X0229.png di folder X
# Deteksi wajah berhasil: X0230.png di folder X
# Deteksi wajah berhasil: X0231.png di folder X
# Deteksi wajah berhasil: X0232.png di folder X
# Deteksi wajah berhasil: X0233.png di folder X
# Deteksi wajah berhasil: X0234.png di folder X
# Deteksi wajah berhasil: X0236.png di folder X
# Deteksi wajah berhasil: X0237.png di folder X
# Deteksi wajah berhasil: X0238.png di folder X
# Deteksi wajah berhasil: X0239.png di folder X
# Deteksi wajah berhasil: X0241.png di folder X
# Deteksi wajah berhasil: X0242.png di folder X
# Deteksi wajah berhasil: X0243.png di folder X
# Deteksi wajah berhasil: X0245.png di folder X
# Deteksi wajah berhasil: X0246.png di folder X
# Deteksi wajah berhasil: X0247.png di folder X
# Deteksi wajah berhasil: X0248.png di folder X
# Deteksi wajah berhasil: X0252.png di folder X
# Deteksi wajah berhasil: X0253.png di folder X
# Deteksi wajah berhasil: X0254.png di folder X
# Deteksi wajah berhasil: X0255.png di folder X
# Deteksi wajah berhasil: X0256.png di folder X
# Deteksi wajah berhasil: X0257.png di folder X
# Deteksi wajah berhasil: X0258.png di folder X
# Deteksi wajah berhasil: X0259.png di folder X
# Deteksi wajah berhasil: X0261.png di folder X
# Deteksi wajah berhasil: X0262.png di folder X
# Deteksi wajah berhasil: X0264.png di folder X
# Deteksi wajah berhasil: X0265.png di folder X
# Deteksi wajah berhasil: X0266.png di folder X
# Deteksi wajah berhasil: X0268.png di folder X
# Deteksi wajah berhasil: X0270.png di folder X
# Deteksi wajah berhasil: X0271.png di folder X
# Deteksi wajah berhasil: X0272.png di folder X
# Deteksi wajah berhasil: X0273.png di folder X
# Deteksi wajah berhasil: X0276.png di folder X
# Deteksi wajah berhasil: X0277.png di folder X
# Deteksi wajah berhasil: X0278.png di folder X
# Deteksi wajah berhasil: X0279.png di folder X
# Deteksi wajah berhasil: X0282.png di folder X
# Deteksi wajah berhasil: X0285.png di folder X
# Deteksi wajah berhasil: X0286.png di folder X
# Deteksi wajah berhasil: X0287.png di folder X
# Deteksi wajah berhasil: X0288.png di folder X
# Deteksi wajah berhasil: X0289.png di folder X
# Deteksi wajah berhasil: X0291.png di folder X
# Deteksi wajah berhasil: X0293.png di folder X
# Deteksi wajah berhasil: X0294.png di folder X
# Deteksi wajah berhasil: X0295.png di folder X
# Deteksi wajah berhasil: X0299.png di folder X
# Deteksi wajah berhasil: X0300.png di folder X
# Deteksi wajah berhasil: X0301.png di folder X
# Deteksi wajah berhasil: X0307.png di folder X
# Deteksi wajah berhasil: X0309.png di folder X
# Deteksi wajah berhasil: X0310.png di folder X
# Deteksi wajah berhasil: X0312.png di folder X
# Deteksi wajah berhasil: X0316.png di folder X
# Deteksi wajah berhasil: X0317.png di folder X
# Deteksi wajah berhasil: X0318.png di folder X
# Deteksi wajah berhasil: X0319.png di folder X
# Deteksi wajah berhasil: X0321.png di folder X
# Deteksi wajah berhasil: X0322.png di folder X
# Deteksi wajah berhasil: X0323.png di folder X
# Deteksi wajah berhasil: X0325.png di folder X
# Deteksi wajah berhasil: X0327.png di folder X
# Deteksi wajah berhasil: X0329.png di folder X
# Deteksi wajah berhasil: X0331.png di folder X
# Deteksi wajah berhasil: X0335.png di folder X
# Deteksi wajah berhasil: X0336.png di folder X
# Deteksi wajah berhasil: X0337.png di folder X
# Deteksi wajah berhasil: X0338.png di folder X
# Deteksi wajah berhasil: X0340.png di folder X
# Deteksi wajah berhasil: X0341.png di folder X
# Deteksi wajah berhasil: X0342.png di folder X
# Deteksi wajah berhasil: X0344.png di folder X
# Deteksi wajah berhasil: X0346.png di folder X
# Deteksi wajah berhasil: X0348.png di folder X
# Deteksi wajah berhasil: X0350.png di folder X
# Deteksi wajah berhasil: X0351.png di folder X
# Deteksi wajah berhasil: X0352.png di folder X
# Deteksi wajah berhasil: X0353.png di folder X
# Deteksi wajah berhasil: X0354.png di folder X
# Deteksi wajah berhasil: X0355.png di folder X
# Deteksi wajah berhasil: X0356.png di folder X
# Deteksi wajah berhasil: X0357.png di folder X
# Deteksi wajah berhasil: X0359.png di folder X
# Deteksi wajah berhasil: X0360.png di folder X
# Deteksi wajah berhasil: X0362.png di folder X
# Deteksi wajah berhasil: X0363.png di folder X
# Deteksi wajah berhasil: X0364.png di folder X
# Deteksi wajah berhasil: X0365.png di folder X
# Deteksi wajah berhasil: X0367.png di folder X
# Deteksi wajah berhasil: X0368.png di folder X
# Deteksi wajah berhasil: X0369.png di folder X
# Deteksi wajah berhasil: X0370.png di folder X
# Deteksi wajah berhasil: X0373.png di folder X
# Deteksi wajah berhasil: X0375.png di folder X
# Deteksi wajah berhasil: X0376.png di folder X
# Deteksi wajah berhasil: X0377.png di folder X
# Deteksi wajah berhasil: X0379.png di folder X
# Deteksi wajah berhasil: X0380.png di folder X
# Deteksi wajah berhasil: X0381.png di folder X
# Deteksi wajah berhasil: X0382.png di folder X
# Deteksi wajah berhasil: X0383.png di folder X
# Deteksi wajah berhasil: X0384.png di folder X
# Deteksi wajah berhasil: X0387.png di folder X
# Deteksi wajah berhasil: X0388.png di folder X
# Deteksi wajah berhasil: X0389.png di folder X
# Deteksi wajah berhasil: X0390.png di folder X
# Deteksi wajah berhasil: X0392.png di folder X
# Deteksi wajah berhasil: X0393.png di folder X
# Deteksi wajah berhasil: X0394.png di folder X
# Deteksi wajah berhasil: X0395.png di folder X
# Deteksi wajah berhasil: X0396.png di folder X
# Deteksi wajah berhasil: X0397.png di folder X
# Deteksi wajah berhasil: X0398.png di folder X
# Deteksi wajah berhasil: X0399.png di folder X
# Deteksi wajah berhasil: X0401.png di folder X
# Deteksi wajah berhasil: X0404.png di folder X
# Deteksi wajah berhasil: X0407.png di folder X
# Deteksi wajah berhasil: X0408.png di folder X
# Deteksi wajah berhasil: X0409.png di folder X
# Deteksi wajah berhasil: X0410.png di folder X
# Deteksi wajah berhasil: X0411.png di folder X
# Deteksi wajah berhasil: X0414.png di folder X
# Deteksi wajah berhasil: X0415.png di folder X
# Deteksi wajah berhasil: X0416.png di folder X
# Deteksi wajah berhasil: X0417.png di folder X
# Deteksi wajah berhasil: X0418.png di folder X
# Deteksi wajah berhasil: X0419.png di folder X
# Deteksi wajah berhasil: X0420.png di folder X
# Deteksi wajah berhasil: X0422.png di folder X
# Deteksi wajah berhasil: X0424.png di folder X
# Deteksi wajah berhasil: X0425.png di folder X
# Deteksi wajah berhasil: X0426.png di folder X
# Deteksi wajah berhasil: X0427.png di folder X
# Deteksi wajah berhasil: X0428.png di folder X
# Deteksi wajah berhasil: X0433.png di folder X
# Deteksi wajah berhasil: X0434.png di folder X
# Deteksi wajah berhasil: X0435.png di folder X
# Deteksi wajah berhasil: X0436.png di folder X
# Deteksi wajah berhasil: X0437.png di folder X
# Deteksi wajah berhasil: X0438.png di folder X
# Deteksi wajah berhasil: X0439.png di folder X
# Deteksi wajah berhasil: X0440.png di folder X
# Deteksi wajah berhasil: X0441.png di folder X
# Deteksi wajah berhasil: X0443.png di folder X
# Deteksi wajah berhasil: X0445.png di folder X
# Deteksi wajah berhasil: X0446.png di folder X
# Deteksi wajah berhasil: X0447.png di folder X
# Deteksi wajah berhasil: X0448.png di folder X
# Deteksi wajah berhasil: X0449.png di folder X
# Deteksi wajah berhasil: X0450.png di folder X
# Deteksi wajah berhasil: X0451.png di folder X
# Deteksi wajah berhasil: X0454.png di folder X
# Deteksi wajah berhasil: X0455.png di folder X
# Deteksi wajah berhasil: X0456.png di folder X
# Deteksi wajah berhasil: X0458.png di folder X
# Deteksi wajah berhasil: X0459.png di folder X
# Deteksi wajah berhasil: X0460.png di folder X
# Deteksi wajah berhasil: X0462.png di folder X
# Deteksi wajah berhasil: X0463.png di folder X
# Deteksi wajah berhasil: X0464.png di folder X
# Deteksi wajah berhasil: X0465.png di folder X
# Deteksi wajah berhasil: X0466.png di folder X
# Deteksi wajah berhasil: X0468.png di folder X
# Deteksi wajah berhasil: X0469.png di folder X
# Deteksi wajah berhasil: X0470.png di folder X
# Deteksi wajah berhasil: X0471.png di folder X
# Deteksi wajah berhasil: X0472.png di folder X
# Deteksi wajah berhasil: X0473.png di folder X
# Deteksi wajah berhasil: X0474.png di folder X
# Deteksi wajah berhasil: X0476.png di folder X
# Deteksi wajah berhasil: X0477.png di folder X
# Deteksi wajah berhasil: X0480.png di folder X
# Deteksi wajah berhasil: X0481.png di folder X
# Deteksi wajah berhasil: X0483.png di folder X
# Deteksi wajah berhasil: X0484.png di folder X
# Deteksi wajah berhasil: X0485.png di folder X
# Deteksi wajah berhasil: X0486.png di folder X
# Deteksi wajah berhasil: X0489.png di folder X
# Deteksi wajah berhasil: X0492.png di folder X
# Deteksi wajah berhasil: X0494.png di folder X
# Deteksi wajah berhasil: X0495.png di folder X
# Deteksi wajah berhasil: X0496.png di folder X
# Deteksi wajah berhasil: X0498.png di folder X
# Deteksi wajah berhasil: X0500.png di folder X
# Deteksi wajah berhasil: X0501.png di folder X
# Deteksi wajah berhasil: X0502.png di folder X
# Deteksi wajah berhasil: X0503.png di folder X
# Deteksi wajah berhasil: X0505.png di folder X
# Deteksi wajah berhasil: X0507.png di folder X
# Deteksi wajah berhasil: X0508.png di folder X
# Deteksi wajah berhasil: X0511.png di folder X
# Deteksi wajah berhasil: X0513.png di folder X
# Deteksi wajah berhasil: X0515.png di folder X
# Deteksi wajah berhasil: X0516.png di folder X
# Deteksi wajah berhasil: X0517.png di folder X
# Deteksi wajah berhasil: X0518.png di folder X
# Deteksi wajah berhasil: X0519.png di folder X
# Deteksi wajah berhasil: X0520.png di folder X
# Deteksi wajah berhasil: X0521.png di folder X
# Deteksi wajah berhasil: X0522.png di folder X
# Deteksi wajah berhasil: X0524.png di folder X
# Deteksi wajah berhasil: X0525.png di folder X
# Deteksi wajah berhasil: X0526.png di folder X
# Deteksi wajah berhasil: X0527.png di folder X
# Deteksi wajah berhasil: X0531.png di folder X
# Deteksi wajah berhasil: X0532.png di folder X
# Deteksi wajah berhasil: X0534.png di folder X
# ...
# Deteksi wajah berhasil: r0131.png di folder r
# Deteksi wajah berhasil: r0132.png di folder r
# Deteksi wajah berhasil: r0134.png di folder r
# Deteksi wajah berhasil: r0135.png di folder r
# Deteksi wajah berhasil: r0136.png di folder r
# Deteksi wajah berhasil: r0137.png di folder r
# Deteksi wajah berhasil: r0138.png di folder r
# Deteksi wajah berhasil: r0140.png di folder r
# Deteksi wajah berhasil: r0142.png di folder r
# Deteksi wajah berhasil: r0143.png di folder r
# Deteksi wajah berhasil: r0144.png di folder r
# Deteksi wajah berhasil: r0145.png di folder r
# Deteksi wajah berhasil: r0146.png di folder r
# Deteksi wajah berhasil: r0148.png di folder r
# Deteksi wajah berhasil: r0153.png di folder r
# Deteksi wajah berhasil: r0154.png di folder r
# Deteksi wajah berhasil: r0155.png di folder r
# Deteksi wajah berhasil: r0156.png di folder r
# Deteksi wajah berhasil: r0157.png di folder r
# Deteksi wajah berhasil: r0158.png di folder r
# Deteksi wajah berhasil: r0159.png di folder r
# Deteksi wajah berhasil: r0161.png di folder r
# Deteksi wajah berhasil: r0162.png di folder r
# Deteksi wajah berhasil: r0166.png di folder r
# Deteksi wajah berhasil: r0167.png di folder r
# Deteksi wajah berhasil: r0170.png di folder r
# Deteksi wajah berhasil: r0171.png di folder r
# Deteksi wajah berhasil: r0172.png di folder r
# Deteksi wajah berhasil: s0001.png di folder s
# Deteksi wajah berhasil: s0002.png di folder s
# Deteksi wajah berhasil: s0003.png di folder s
# Deteksi wajah berhasil: s0005.png di folder s
# Deteksi wajah berhasil: s0006.png di folder s
# Deteksi wajah berhasil: s0008.png di folder s
# Deteksi wajah berhasil: s0010.png di folder s
# Deteksi wajah berhasil: s0011.png di folder s
# Deteksi wajah berhasil: s0012.png di folder s
# Deteksi wajah berhasil: s0015.png di folder s
# Deteksi wajah berhasil: s0018.png di folder s
# Deteksi wajah berhasil: s0019.png di folder s
# Deteksi wajah berhasil: s0020.png di folder s
# Deteksi wajah berhasil: s0021.png di folder s
# Deteksi wajah berhasil: s0023.png di folder s
# Deteksi wajah berhasil: s0024.png di folder s
# Deteksi wajah berhasil: s0026.png di folder s
# Deteksi wajah berhasil: s0028.png di folder s
# Deteksi wajah berhasil: s0029.png di folder s
# Deteksi wajah berhasil: s0031.png di folder s
# Deteksi wajah berhasil: s0034.png di folder s
# Deteksi wajah berhasil: s0036.png di folder s
# Deteksi wajah berhasil: s0038.png di folder s
# Deteksi wajah berhasil: s0039.png di folder s
# Deteksi wajah berhasil: s0041.png di folder s
# Deteksi wajah berhasil: s0042.png di folder s
# Deteksi wajah berhasil: s0043.png di folder s
# Deteksi wajah berhasil: s0044.png di folder s
# Deteksi wajah berhasil: s0045.png di folder s
# Deteksi wajah berhasil: s0046.png di folder s
# Deteksi wajah berhasil: s0049.png di folder s
# Deteksi wajah berhasil: s0050.png di folder s
# Deteksi wajah berhasil: s0051.png di folder s
# Deteksi wajah berhasil: s0053.png di folder s
# Deteksi wajah berhasil: s0055.png di folder s
# Deteksi wajah berhasil: s0056.png di folder s
# Deteksi wajah berhasil: s0057.png di folder s
# Deteksi wajah berhasil: s0058.png di folder s
# Deteksi wajah berhasil: s0059.png di folder s
# Deteksi wajah berhasil: s0060.png di folder s
# Deteksi wajah berhasil: s0062.png di folder s
# Deteksi wajah berhasil: s0063.png di folder s
# Deteksi wajah berhasil: s0065.png di folder s
# Deteksi wajah berhasil: s0066.png di folder s
# Deteksi wajah berhasil: s0067.png di folder s
# Deteksi wajah berhasil: s0068.png di folder s
# Deteksi wajah berhasil: s0070.png di folder s
# Deteksi wajah berhasil: s0071.png di folder s
# Deteksi wajah berhasil: s0076.png di folder s
# Deteksi wajah berhasil: s0077.png di folder s
# Deteksi wajah berhasil: s0078.png di folder s
# Deteksi wajah berhasil: s0080.png di folder s
# Deteksi wajah berhasil: s0081.png di folder s
# Deteksi wajah berhasil: s0082.png di folder s
# Deteksi wajah berhasil: s0083.png di folder s
# Deteksi wajah berhasil: s0084.png di folder s
# Deteksi wajah berhasil: s0085.png di folder s
# Deteksi wajah berhasil: s0086.png di folder s
# Deteksi wajah berhasil: s0088.png di folder s
# Deteksi wajah berhasil: s0089.png di folder s
# Deteksi wajah berhasil: s0090.png di folder s
# Deteksi wajah berhasil: s0091.png di folder s
# Deteksi wajah berhasil: s0092.png di folder s
# Deteksi wajah berhasil: s0094.png di folder s
# Deteksi wajah berhasil: s0096.png di folder s
# Deteksi wajah berhasil: s0097.png di folder s
# Deteksi wajah berhasil: s0099.png di folder s
# Deteksi wajah berhasil: s0100.png di folder s
# Deteksi wajah berhasil: s0103.png di folder s
# Deteksi wajah berhasil: s0104.png di folder s
# Deteksi wajah berhasil: s0107.png di folder s
# Deteksi wajah berhasil: s0108.png di folder s
# Deteksi wajah berhasil: s0128.png di folder s
# Deteksi wajah berhasil: s0129.png di folder s
# Deteksi wajah berhasil: s0130.png di folder s
# Deteksi wajah berhasil: s0131.png di folder s
# Deteksi wajah berhasil: s0132.png di folder s
# Deteksi wajah berhasil: s0135.png di folder s
# Deteksi wajah berhasil: s0138.png di folder s
# Deteksi wajah berhasil: s0140.png di folder s
# Deteksi wajah berhasil: s0141.png di folder s
# Deteksi wajah berhasil: s0143.png di folder s
# Deteksi wajah berhasil: s0145.png di folder s
# Deteksi wajah berhasil: s0147.png di folder s
# Deteksi wajah berhasil: s0148.png di folder s
# Deteksi wajah berhasil: s0149.png di folder s
# Deteksi wajah berhasil: s0150.png di folder s
# Deteksi wajah berhasil: s0153.png di folder s
# Deteksi wajah berhasil: s0154.png di folder s
# Deteksi wajah berhasil: s0155.png di folder s
# Deteksi wajah berhasil: s0158.png di folder s
# Deteksi wajah berhasil: s0159.png di folder s
# Deteksi wajah berhasil: s0161.png di folder s
# Deteksi wajah berhasil: s0164.png di folder s
# Deteksi wajah berhasil: s0165.png di folder s
# Deteksi wajah berhasil: s0166.png di folder s
# Deteksi wajah berhasil: s0168.png di folder s
# Deteksi wajah berhasil: s0169.png di folder s
# Deteksi wajah berhasil: s0171.png di folder s
# Deteksi wajah berhasil: s0173.png di folder s
# Deteksi wajah berhasil: s0174.png di folder s
# Deteksi wajah berhasil: s0175.png di folder s
# Deteksi wajah berhasil: s0176.png di folder s
# Deteksi wajah berhasil: s0177.png di folder s
# Deteksi wajah berhasil: s0178.png di folder s
# Deteksi wajah berhasil: s0180.png di folder s
# Deteksi wajah berhasil: s0181.png di folder s
# Deteksi wajah berhasil: s0182.png di folder s
# Deteksi wajah berhasil: s0184.png di folder s
# Deteksi wajah berhasil: s0185.png di folder s
# Deteksi wajah berhasil: s0186.png di folder s
# Deteksi wajah berhasil: s0187.png di folder s
# Deteksi wajah berhasil: s0188.png di folder s
# Deteksi wajah berhasil: s0189.png di folder s
# Deteksi wajah berhasil: s0190.png di folder s
# Deteksi wajah berhasil: s0191.png di folder s
# Deteksi wajah berhasil: s0192.png di folder s
# Deteksi wajah berhasil: s0193.png di folder s
# Deteksi wajah berhasil: s0194.png di folder s
# Deteksi wajah berhasil: s0196.png di folder s
# Deteksi wajah berhasil: s0201.png di folder s
# Deteksi wajah berhasil: s0202.png di folder s
# Deteksi wajah berhasil: s0203.png di folder s
# Deteksi wajah berhasil: s0205.png di folder s
# Deteksi wajah berhasil: s0206.png di folder s
# Deteksi wajah berhasil: s0208.png di folder s
# Deteksi wajah berhasil: s0209.png di folder s
# Deteksi wajah berhasil: s0212.png di folder s
# Deteksi wajah berhasil: s0214.png di folder s
# Deteksi wajah berhasil: s0215.png di folder s
# Deteksi wajah berhasil: s0216.png di folder s
# Deteksi wajah berhasil: s0217.png di folder s
# Deteksi wajah berhasil: s0219.png di folder s
# Deteksi wajah berhasil: s0220.png di folder s
# Deteksi wajah berhasil: s0223.png di folder s
# Deteksi wajah berhasil: s0224.png di folder s
# Deteksi wajah berhasil: s0225.png di folder s
# Deteksi wajah berhasil: s0226.png di folder s
# Deteksi wajah berhasil: s0227.png di folder s
# Deteksi wajah berhasil: s0228.png di folder s
# Deteksi wajah berhasil: s0229.png di folder s
# Deteksi wajah berhasil: s0231.png di folder s
# Deteksi wajah berhasil: s0233.png di folder s
# Deteksi wajah berhasil: s0235.png di folder s
# Deteksi wajah berhasil: s0236.png di folder s
# Deteksi wajah berhasil: s0237.png di folder s
# Deteksi wajah berhasil: s0238.png di folder s
# Deteksi wajah berhasil: s0239.png di folder s
# Deteksi wajah berhasil: s0240.png di folder s
# Deteksi wajah berhasil: s0241.png di folder s
# Deteksi wajah berhasil: s0242.png di folder s
# Deteksi wajah berhasil: s0244.png di folder s
# Deteksi wajah berhasil: s0245.png di folder s
# Deteksi wajah berhasil: s0247.png di folder s
# Deteksi wajah berhasil: s0248.png di folder s
# Deteksi wajah berhasil: s0252.png di folder s
# Deteksi wajah berhasil: s0253.png di folder s
# Deteksi wajah berhasil: s0254.png di folder s
# Deteksi wajah berhasil: s0255.png di folder s
# Deteksi wajah berhasil: s0256.png di folder s
# Deteksi wajah berhasil: s0257.png di folder s
# Deteksi wajah berhasil: s0258.png di folder s
# Deteksi wajah berhasil: s0259.png di folder s
# Deteksi wajah berhasil: s0260.png di folder s
# Deteksi wajah berhasil: s0261.png di folder s
# Deteksi wajah berhasil: s0262.png di folder s
# Deteksi wajah berhasil: s0263.png di folder s
# Deteksi wajah berhasil: s0264.png di folder s
# Deteksi wajah berhasil: s0266.png di folder s
# Deteksi wajah berhasil: s0267.png di folder s
# Deteksi wajah berhasil: s0268.png di folder s
# Deteksi wajah berhasil: s0270.png di folder s
# Deteksi wajah berhasil: s0271.png di folder s
# Deteksi wajah berhasil: s0273.png di folder s
# Deteksi wajah berhasil: s0274.png di folder s
# Deteksi wajah berhasil: s0275.png di folder s
# Deteksi wajah berhasil: s0277.png di folder s
# Deteksi wajah berhasil: s0278.png di folder s
# Deteksi wajah berhasil: s0279.png di folder s
# Deteksi wajah berhasil: s0280.png di folder s
# Deteksi wajah berhasil: s0281.png di folder s
# Deteksi wajah berhasil: s0285.png di folder s
# Deteksi wajah berhasil: s0286.png di folder s
# Deteksi wajah berhasil: s0293.png di folder s
# Deteksi wajah berhasil: s0295.png di folder s
# Deteksi wajah berhasil: s0296.png di folder s
# Deteksi wajah berhasil: s0298.png di folder s
# Deteksi wajah berhasil: s0301.png di folder s
# Deteksi wajah berhasil: s0302.png di folder s
# Deteksi wajah berhasil: s0303.png di folder s
# Deteksi wajah berhasil: s0305.png di folder s
# Deteksi wajah berhasil: s0308.png di folder s
# Deteksi wajah berhasil: s0311.png di folder s
# Deteksi wajah berhasil: s0312.png di folder s
# Deteksi wajah berhasil: s0313.png di folder s
# Deteksi wajah berhasil: s0315.png di folder s
# Deteksi wajah berhasil: s0316.png di folder s
# Deteksi wajah berhasil: s0317.png di folder s
# Deteksi wajah berhasil: s0319.png di folder s
# Deteksi wajah berhasil: s0320.png di folder s
# Deteksi wajah berhasil: s0321.png di folder s
# Deteksi wajah berhasil: s0322.png di folder s
# Deteksi wajah berhasil: s0324.png di folder s
# Deteksi wajah berhasil: s0325.png di folder s
# Deteksi wajah berhasil: s0326.png di folder s
# Deteksi wajah berhasil: s0327.png di folder s
# Deteksi wajah berhasil: s0328.png di folder s
# Deteksi wajah berhasil: s0330.png di folder s
# Deteksi wajah berhasil: s0331.png di folder s
# Deteksi wajah berhasil: s0333.png di folder s
# Deteksi wajah berhasil: s0334.png di folder s
# Deteksi wajah berhasil: s0335.png di folder s
# Deteksi wajah berhasil: s0337.png di folder s
# Deteksi wajah berhasil: s0338.png di folder s
# Deteksi wajah berhasil: s0339.png di folder s
# Deteksi wajah berhasil: s0340.png di folder s
# Deteksi wajah berhasil: s0341.png di folder s
# Deteksi wajah berhasil: s0344.png di folder s
# Deteksi wajah berhasil: s0355.png di folder s
# Deteksi wajah berhasil: s0356.png di folder s
# Deteksi wajah berhasil: s0357.png di folder s
# Deteksi wajah berhasil: s0358.png di folder s
# Deteksi wajah berhasil: s0359.png di folder s
# Deteksi wajah berhasil: s0363.png di folder s
# Deteksi wajah berhasil: s0364.png di folder s
# Deteksi wajah berhasil: s0365.png di folder s
# Deteksi wajah berhasil: s0366.png di folder s
# Deteksi wajah berhasil: s0368.png di folder s
# Deteksi wajah berhasil: s0369.png di folder s
# Deteksi wajah berhasil: s0371.png di folder s
# Deteksi wajah berhasil: s0372.png di folder s
# Deteksi wajah berhasil: s0373.png di folder s
# Deteksi wajah berhasil: s0374.png di folder s
# Deteksi wajah berhasil: s0375.png di folder s
# Deteksi wajah berhasil: s0376.png di folder s
# Deteksi wajah berhasil: s0377.png di folder s
# Deteksi wajah berhasil: s0378.png di folder s
# Deteksi wajah berhasil: s0379.png di folder s
# Deteksi wajah berhasil: s0380.png di folder s
# Deteksi wajah berhasil: s0381.png di folder s
# Deteksi wajah berhasil: s0382.png di folder s
# Deteksi wajah berhasil: s0385.png di folder s
# Deteksi wajah berhasil: s0386.png di folder s
# Deteksi wajah berhasil: s0387.png di folder s
# Deteksi wajah berhasil: s0388.png di folder s
# Deteksi wajah berhasil: s0389.png di folder s
# Deteksi wajah berhasil: s0390.png di folder s
# Deteksi wajah berhasil: s0391.png di folder s
# Deteksi wajah berhasil: s0393.png di folder s
# Deteksi wajah berhasil: s0394.png di folder s
# Deteksi wajah berhasil: s0395.png di folder s
# Deteksi wajah berhasil: s0396.png di folder s
# Deteksi wajah berhasil: s0397.png di folder s
# Deteksi wajah berhasil: s0398.png di folder s
# Deteksi wajah berhasil: s0399.png di folder s
# Deteksi wajah berhasil: s0401.png di folder s
# Deteksi wajah berhasil: s0402.png di folder s
# Deteksi wajah berhasil: s0404.png di folder s
# Deteksi wajah berhasil: s0405.png di folder s
# Deteksi wajah berhasil: s0407.png di folder s
# Deteksi wajah berhasil: s0408.png di folder s
# Deteksi wajah berhasil: s0409.png di folder s
# Deteksi wajah berhasil: s0410.png di folder s
# Deteksi wajah berhasil: s0413.png di folder s
# Deteksi wajah berhasil: s0415.png di folder s
# Deteksi wajah berhasil: s0416.png di folder s
# Deteksi wajah berhasil: s0417.png di folder s
# Deteksi wajah berhasil: s0418.png di folder s
# Deteksi wajah berhasil: s0420.png di folder s
# Deteksi wajah berhasil: s0422.png di folder s
# Deteksi wajah berhasil: s0423.png di folder s
# Deteksi wajah berhasil: s0424.png di folder s
# Deteksi wajah berhasil: s0426.png di folder s
# Deteksi wajah berhasil: s0427.png di folder s
# Deteksi wajah berhasil: s0428.png di folder s
# Deteksi wajah berhasil: s0429.png di folder s
# Deteksi wajah berhasil: s0431.png di folder s
# Deteksi wajah berhasil: s0432.png di folder s
# Deteksi wajah berhasil: s0435.png di folder s
# Deteksi wajah berhasil: s0437.png di folder s
# Deteksi wajah berhasil: s0438.png di folder s
# Deteksi wajah berhasil: s0440.png di folder s
# Deteksi wajah berhasil: s0443.png di folder s
# Deteksi wajah berhasil: s0444.png di folder s
# Deteksi wajah berhasil: s0445.png di folder s
# Deteksi wajah berhasil: s0446.png di folder s
# Deteksi wajah berhasil: s0447.png di folder s
# Deteksi wajah berhasil: s0448.png di folder s
# Deteksi wajah berhasil: s0449.png di folder s
# Deteksi wajah berhasil: s0451.png di folder s
# Deteksi wajah berhasil: s0452.png di folder s
# Deteksi wajah berhasil: s0454.png di folder s
# Deteksi wajah berhasil: s0455.png di folder s
# Deteksi wajah berhasil: s0457.png di folder s
# Deteksi wajah berhasil: s0458.png di folder s
# Deteksi wajah berhasil: s0459.png di folder s
# Deteksi wajah berhasil: s0460.png di folder s
# Deteksi wajah berhasil: s0461.png di folder s
# Deteksi wajah berhasil: s0463.png di folder s
# Deteksi wajah berhasil: s0464.png di folder s
# Deteksi wajah berhasil: s0466.png di folder s
# Deteksi wajah berhasil: s0467.png di folder s
# Deteksi wajah berhasil: s0471.png di folder s
# Deteksi wajah berhasil: s0473.png di folder s
# Deteksi wajah berhasil: s0474.png di folder s
# Deteksi wajah berhasil: s0476.png di folder s
# Deteksi wajah berhasil: s0480.png di folder s
# Deteksi wajah berhasil: s0481.png di folder s
# Deteksi wajah berhasil: s0483.png di folder s
# Deteksi wajah berhasil: s0484.png di folder s
# Deteksi wajah berhasil: s0485.png di folder s
# Deteksi wajah berhasil: s0487.png di folder s
# Deteksi wajah berhasil: s0488.png di folder s
# Deteksi wajah berhasil: s0489.png di folder s
# Deteksi wajah berhasil: s0490.png di folder s
# Deteksi wajah berhasil: s0491.png di folder s
# Deteksi wajah berhasil: s0493.png di folder s
# Deteksi wajah berhasil: s0494.png di folder s
# Deteksi wajah berhasil: s0495.png di folder s

# %%
# Print laporan akhir
print("--- Laporan Deteksi Wajah ---")
print(f"Total jumlah file untuk dideteksi: {total_all_files}")
print(f"Jumlah file untuk dideteksi (Drowsy): {total_files} (Drowsy)")
print(f"Jumlah file untuk dideteksi (Non Drowsy): {total_files} (Non Drowsy)")
print(f"\nTotal jumlah file berhasil dideteksi: {detected_all_files}")
print(f"Jumlah file berhasil dideteksi (Drowsy): {detected_files} (Drowsy)")
print(f"Jumlah file berhasil dideteksi (Non Drowsy): {detected_files} (Non Drowsy)")
print(f"\nTotal jumlah file tidak berhasil dideteksi: {undetected_all_files}")
print(f"Jumlah file tidak berhasil dideteksi (Drowsy): {undetected_files} (Drowsy)")
print(f"Jumlah file tidak berhasil dideteksi (Non Drowsy): {undetected_files} (Non Drowsy)")
# Out:
# --- Laporan Deteksi Wajah ---
# Total jumlah file untuk dideteksi: 5524
# Jumlah file untuk dideteksi (Drowsy): 1346 (Drowsy)
# Jumlah file untuk dideteksi (Non Drowsy): 1346 (Non Drowsy)
#
# Total jumlah file berhasil dideteksi: 5521
# Jumlah file berhasil dideteksi (Drowsy): 1346 (Drowsy)
# Jumlah file berhasil dideteksi (Non Drowsy): 1346 (Non Drowsy)
#
# Total jumlah file tidak berhasil dideteksi: 3
# Jumlah file tidak berhasil dideteksi (Drowsy): 0 (Drowsy)
# Jumlah file tidak berhasil dideteksi (Non Drowsy): 0 (Non Drowsy)

# %%
# Visualisasi untuk perbandingan gambar asli dan setelah deteksi
def display_comparison_images(file_path, detected_file_path, title):
    original_img = Image.open(file_path)
    detected_img = Image.open(detected_file_path)

    # Menampilkan gambar
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))

    axes[0].imshow(original_img)
    axes[0].set_title(f"{title} - Original Image")
    axes[0].axis('off')

    axes[1].imshow(detected_img)
    axes[1].set_title(f"{title} - Detect Image")
    axes[1].axis('off')

    plt.show()

# Pilih gambar acak dari kategori Drowsy dan Non Drowsy untuk visualisasi
if detected_file_paths_all['Drowsy']:
    random_drowsy_file = random.choice(detected_file_paths_all['Drowsy'])
    random_drowsy_detected = os.path.join(detectface_path, 'Drowsy', random_drowsy_file.split('|')[-2], random_drowsy_file.split('|')[-1])
    display_comparison_images(random_drowsy_file, random_drowsy_detected, "Drowsy Image")

if detected_file_paths_all['Non Drowsy']:
    random_non_drowsy_file = random.choice(detected_file_paths_all['Non Drowsy'])
    random_non_drowsy_detected = os.path.join(detectface_path, 'Non Drowsy', random_non_drowsy_file.split('/')[-2], random_non_drowsy_file.split('/')[-1])
    display_comparison_images(random_non_drowsy_file, random_non_drowsy_detected, "Non Drowsy Image")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 22
#      20 if detected_file_paths_all['Drowsy']:
#      21     random_drowsy_file = random.choice(detected_file_paths_all['Drowsy'])
# ---> 22     random_drowsy_detected = os.path.join(detectface_path, 'Drowsy', random_drowsy_file.split('|')[-2], random_drowsy_file.split('|')[-1])
#      23     display_comparison_images(random_drowsy_file, random_drowsy_detected, "Drowsy Image")
#      25 if detected_file_paths_all['Non Drowsy']:
#
# IndexError: list index out of range
